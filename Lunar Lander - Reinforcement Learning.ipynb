# %%
from lunar_lander_controller import *

# %%
lunar_lander = lunar_lander_controller("firefox")
lunar_lander.q_network_model()

# %%
lunar_lander.train(discount_rate=0.9, episode_num=10)
# Out:
# Episode  1
# Center / Go
# Right / No-Go
# Left / No-Go
# Left / Go
# Right / No-Go
# Center / No-Go
# Right / No-Go
# Center / No-Go
# Right / No-Go
# Center / No-Go
# Right / No-Go
# Center / No-Go
# Right / No-Go
# Center / No-Go
# Left / No-Go
# Right / Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Center / No-Go
# Left / Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Center / No-Go
# Right / Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Left / No-Go
# Center / Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# Right / No-Go
# ...
